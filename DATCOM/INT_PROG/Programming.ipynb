# %% [markdown]
# # Introducción a la Programación para Ciencia de Datos
# ## Lenguaje de programación R
# _Rocío Romero Zaliz_ - rocio@decsai.ugr.es

# %% [markdown]
# # Estructuras de programación
#
# * R es un lenguaje estructurado en bloques (como C, C++, Python, Perl, etc.).
# * Los bloques están delimitados por llaves, mientras que las sentencias están separadas por caracteres de nueva línea u, opcionalmente, por punto y coma.
# * Al igual que con muchos lenguajes de scripting, no "declaramos" variables en R, por lo tanto tenemos que tener cuidado con los posibles problemas de alcance de variables.
#
# ## Operadores básicos de R
# ![basic.png](attachment:basic.png)

# %% [markdown]
# ## Sentencias de control: if-else
#
# La sintaxis para if-else es la siguiente:
#
# >if (r == 4) {
#      x <- 1
#  } else {
#      x <- 3
#      y <- 4
#  }

# %%
r <- 3
x <- 0
y <- 0

if (r == 4) {  
 x <- 1  
} else {  
 x <- 3  
 y <- 4 
}

print(x)
print(y)
# Out:
# [1] 3
# [1] 4

# %% [markdown]
# Una sentencia if-else funciona como una llamada a una función, y como tal, devuelve el último valor asignado.

# %%
print(if (x == 2) y <- x else y <- x+1)
# Out:
# [1] 4

# %%
y <- if(x == 2) x else x+1 # Recomendación: esta es la forma más elegante... usad esta porfaplis
y
# Out:
# [1] 4

# %%
# Error!
x <- 1:10
y <- if (x == 2) x else x+1
y
# Out:
# Error in if (x == 2) x else x + 1: the condition has length > 1
# Traceback:

# %%
x == 2

# %% [markdown]
# Cuando trabajamos con vectores, utilizamo la función `ifelse`.
#
# La forma es: `ifelse(b,u,v)` donde `b` es un vector booleano, y `u` y `v` son vectores.
#
# El valor de retorno es a su vez un vector: el elemento `i` es `u[i]` si `b[i]` es verdadero, o `v[i]` si `b[i]` es falso.

# %%
x <- 1:10
y <- ifelse(x == 2, x, x+1)
y

# %%
x <- 1:10
ifelse(x %% 2 == 0, "par", "impar")

# %%
x <- c(5,2,9,12)
y <- ifelse(x > 6, 2*x, 3*x)
y

# %% [markdown]
# ## Declaraciones de control: ciclos
#
# Uno de los temas principales de la programación en R es evitar los ciclos si es posible; si no, mantener los ciclos lo más simple posible.
#
# Tenemos:
# * Ciclos For
# * Ciclos While
# * Ciclos de repetición

# %% [markdown]
# ### For loops

# %%
# Sólo un ejemplo, por favor no codifiques así en R... Por faaaaaaaa... :'(
for (n in 1:5) print(n)

# %%
# In R use print(1:5)
print(1:5)

# %%
# Sólo un ejemplo, por favor no codifiques así en R... Por faaaaaaaa...
print(x)

k <- 0
for (n in x) {
   if (n %% 2 == 1) k <- k+1  
} 
k

# %%
# In R use...
sum(x %% 2 == 1)

# %%
# He aquí el porque...
k <- 0
x <- 1:10000000
system.time(for (n in x) if (n %% 2 == 1) k <- k+1)
system.time(sum(x %% 2 == 1))

# %% [markdown]
# ### While loops

# %%
# Sólo un ejemplo, por favor no codifiques así en R... Por faaaaaaaa...
print(x[1:10])

i <- 1
while ((i < length(x)) & (x[i] != 9)) {
    i <- i+1
}
i

# %%
# In R use...
which(x == 9)

# %%
# He aquí el porque...
i <- 1
x <- 1:1000000
system.time(while ((i < length(x)) && (x[i] != 999999)) i <- i+1)
system.time(which(x == 999999))

# %% [markdown]
# ### Repeat loops

# %%
# Sólo un ejemplo, por favor no codifiquéis así en R...
# Honestamente odio los repeats en R... Odio el `break` en cualquier lenguaje de programación
# Llamadme "negacionista del break"

i <- 0
repeat {
    i <- i+1
    if ((i > length(x)) || (x[i] == 9)) break
}
i

# %%
# In R use...
which(x == 9)

# %%
# This is why:
i <- 1
x <- 1:100000
system.time(repeat {
    i <- i+1
    if ((i > length(x)) || (x[i] == 99999)) break
    })
system.time(which(x == 99999)[1])

# %% [markdown]
# # Looping: the R way
#
# En R tienes más opciones a la hora de hacer cálculos de repetición:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### La función apply
#
# Esta es la forma general de apply para matrices:
#
# `apply(m, dimcode, f, fargs)`
#
# donde:
# * `m` es la matriz o array.
# * `Dimcode` es la dimensión, igual a 1 si la función se aplica a las filas o a 2 si se aplica a las columnas.
# * `f` es la función a aplicar.
# * `fargs` es un conjunto opcional de argumentos a suministrar a `f`.

# %%
z <- matrix(c(1,1,2,2,3,3), nrow=3, byrow=TRUE)
print(z)

# %%
apply(z, 1, mean)

# %%
apply(z, 1, mean, na.rm = TRUE)

# %%
apply(z, 2, mean)

# %%
print(apply(z, 1:2, mean))

# %%
apply(z, 1, function(x) {print(x) ; x ^ 2})

# %%
apply(z, 1, \(x) {print(x) ; x ^ 2})

# %% [markdown]
# #### La función lapply
#
# Devuelve una lista de la misma longitud que los datos de entrada X, cada uno de cuyos elementos es el resultado de aplicar una función al elemento correspondiente de X.

# %%
w <- list(vector=c(1,2,3), matriz=matrix(1,nrow=2,ncol=2))
w

# %%
lapply(w, mean)

# %%
suma <- function(x = 1, y = 5) {
    x + y
}

# %%
print(lapply(1:10, suma, x = 2))

# %%
lapply

# %% [markdown]
# #### La función sapply
#
# Se aplica sobre un objeto y devuelve un objeto simplificado (un vector) si es posible.

# %%
z

# %%
out1 <- lapply(z, mean)
print(out1)

# %%
out <- sapply(z, mean)
print(out)

# %%
?sapply

# %%
out <- unlist(lapply(z, mean))
print(out)
class(out)

# %%
df1 <- data.frame(uno=1:4, dos=c("hola", "mundo", "muy", "cruel"))
df1

# %%
apply(df1, 1, mean)

# %%
apply(df1, 2, mean)

# %%
apply(df1, 1:2, mean)

# %%
df1

# %%
as.list(df1)

# %%
lapply(df1, mean)

# %% [markdown]
# # Mejora del rendimiento: velocidad y memoria
#
# * Para tener un programa que funcione rápido, puede que necesites utilizar más espacio de memoria.
# * Por otro lado, para conservar espacio de memoria, puede que tenga que conformarse con un código más lento.
# * R es un lenguaje interpretado.
# * Muchos de los comandos están escritos en C y por lo tanto se ejecutan en código máquina rápido. Pero otros comandos, y su propio código R, son R puro y por lo tanto interpretado.
# * Todos los objetos de una sesión de R se almacenan en memoria.
# * Más precisamente, todos los objetos se almacenan en el espacio de direcciones de memoria de R.
# * Optimice su código R a través de la vectorización, el uso de la compilación byte-code y otros enfoques.
# * Escriba las partes clave, intensivas en CPU, de su código en un lenguaje compilado como C/C++.
# * Escriba su código en alguna forma de R paralelo.

# %% [markdown]
# ## Vectorización
#
# ### Ciclos:
#  * Es importante entender que simplemente reescribir el código para evitar bucles no necesariamente hará que el código sea más rápido.
#  * Sin embargo, en algunos casos, se puede conseguir un aumento drástico de la velocidad, normalmente a través de la vectorización.
#
# Compare estas dos líneas de código:
#
# > `for (i in 1:length(x)) z[i] <- x[i] + y[i]`
#
# vs.
#
# > `z <- x + y `

# %%
x <- runif(1000000)
y <- runif(1000000)
z <- vector(length=1000000)
system.time(for (i in 1:length(x)) z[i] <- x[i] + y[i])

# %%
system.time(z <- x + y)

# %% [markdown]
# * Ejemplos de otras funciones vectorizadas que pueden acelerar el código son `ifelse()`, `which()`, `any()`, `all()`, `cumsum()`, y `cumprod()`.
# * En el caso de matrices, puede utilizar `rowSums()`, `colSums()`, etc.
# * En configuraciones del tipo "todas las combinaciones posibles", `combn()`, `outer()`, `lower.tri()`, `upper.tri()`, o `expand.grid()` pueden ser justo lo que necesitas.
# * Aunque `apply()` elimina un bucle explícito, en realidad está implementada en R en lugar de en C, por lo que normalmente no acelerará su código. Sin embargo, las otras funciones apply, como `lapply()`, pueden ser muy útiles para acelerar su código.

# %%
outer(1:5, 1:5, "+")

# %% [markdown]
# ## Mejora del rendimiento
#
# <b>Ejemplo 1</b>: Algoritmo lento en R

# %%
xs <- runif(10000)
print(xs)
res <- c()

# This is slow!
system.time(for (x in xs) res <- c(res, sqrt(x)))

# %% [markdown]
# <b>Ejemplo 1</b>: Algoritmo rápido en R

# %%
seq_along(xs)

# %%
res <- numeric(length(xs))

system.time(for (i in seq_along(xs)) res[i] <- sqrt(xs[i]))

# %%
system.time(sqrt(xs))

# %% [markdown]
# <b>Ejemplo 2</b>: Algoritmo lento en R

# %%
amat <- matrix(1:20, nrow=4)
bmat <- matrix(NA, nrow(amat)/2, ncol(amat))

print(amat)
print(bmat)

system.time(for(i in 1:nrow(bmat)) bmat[i,] <- amat[2*i-1,] * amat[2*i,])
            
print(bmat)

# %% [markdown]
# <b>Ejemplo 1</b>: Algoritmo rápido en R

# %%
system.time(bmat2 <- amat[seq(1, nrow(amat), by=2),] * amat[seq(2, nrow(amat), by=2),])

print(bmat2)

# %% [markdown]
# <b>Ejemplo 3</b>: Algoritmo lento en R
#
# * Supongamos que queremos encontrar todos los conjuntos de tres enteros positivos que suman 6, donde el orden importa:

# %%
the.seq <- 1:3

# %%
#for (x in the.seq) {
#    for (y in the.seq) {
#        for (z in the.seq) {
#            if (x + y + z == 6) cat(x, y, z, "\n")
#        }
#    }
#}
#
#cat("\n")

system.time(for (x in the.seq) { for (y in the.seq) { for (z in the.seq) { if (x + y + z == 6) cat(x, y, z, "\n")}}})

# %%
print(outer(the.seq, the.seq, "+"))

# %%
print(outer(outer(the.seq, the.seq, "+"), the.seq, "+"))

# %%
which(outer(outer(the.seq, the.seq, "+"), the.seq, "+") == 6)

# %%
which(outer(outer(the.seq, the.seq, "+"), the.seq, "+") == 6, arr.ind=TRUE)

# %%
system.time(which(outer(outer(the.seq, the.seq, "+"), the.seq, "+") == 6, arr.ind=TRUE))

# %% [markdown]
# ## Vectorizar en exceso
#
# * Es bueno querer vectorizar cuando no hay una manera efectiva de hacerlo. Es malo intentarlo de todos modos.
# * Un reflejo común es usar una función de la familia apply. **Esto no es vectorización, es ocultar bucles.**
# * Utilice un bucle for explícito cuando cada iteración sea una tarea no trivial. Pero un bucle simple puede expresarse de forma más clara y compacta usando una función apply.

# %% [markdown]
# ## Reflexiones finales
#
# * Algunas cosas no son posibles de vectorizar.
# * Si necesitas usar un bucle, entonces:
#     * Ponga todo lo que pueda fuera de los bucles como sea posible.
#     * Haz el número de iteraciones lo más pequeño posible.

# %% [markdown]
# ![image.png](attachment:image.png) ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # References
#
# * Gaston Sanchez. Handling and Processing Strings in R. https://www.gastonsanchez.com/Handling_and_Processing_Strings_in_R.pdf
# * Norman Matloff. 2011. The Art of R Programming: A Tour of Statistical Software Design (1st ed.). No Starch Press, San Francisco, CA, USA.
# * Patrick Burns. 2011. The R Inferno.

# %% [markdown]
# # Ejercicios extra
# http://r-tutorials.com

# %% [markdown]
# ## Víctimas del Titanic - Utiliza el conjunto de datos estándar `titanic`

# %%
help(Titanic)

# %%
dim(Titanic)

# %%
Titanic

# %% [markdown]
# * Utiliza la función de apply adecuada para obtener la suma de hombres y mujeres a bordo.

# %% [markdown]
# * Obtener una tabla con la suma de supervivientes vs sexo.

# %% [markdown]
# * Obtener una tabla con la suma de pasajeros por sexo vs edad.

# %% [markdown]
# ## Extraer elementos de una lista de matrices

# %%
first <- matrix(38:67, 3)
second <- matrix(56:91, 3)
third <- matrix(82:147, 3)
fourth <- matrix(46:95, 5)

listobj <- list(first, second, third, fourth)
listobj

# %% [markdown]
# * Extraer la segunda columna de la lista de matrices (de cada matriz individual).

# %% [markdown]
# * Extraer la tercera fila de la lista de matrices.

# %% [markdown]
# ## Usando la familia 'apply' para trabajar con clases de data.frames

# %% [markdown]
# * Averiguar qué columna del iris no es numérica.

# %%
iris

# %% [markdown]
# ## Cálculo de módulo en una matriz

# %%
mymatrix <- matrix(data = c(6,34,923,5,0, 112:116, 5,9,34,76,2, 545:549), nrow = 5)
mymatrix

# %% [markdown]
# * Utilice `apply` para calcular el módulo 10 en cada valor de la matriz. La nueva matriz contiene el resto de la división módulo.

# %% [markdown]
# ## Aplicando nuestras propias funciones...

# %% [markdown]
# * Imprime para cada elemento en `mymatrix` si es menor que 100 (True) o no (False).

# %% [markdown]
# ## Ejercicios
# Se pueden hacer todos sin necesidad de bucles explícitos... pensad... pensad...
#
# 1. Crear una función "creciente" que indique si los elementos de un array dado son estrictamente crecientes. No se permite ordenar el vector.
# 2. Crear una función "montecarlo" que calcule la estimación de la integral dada:
#  >$\int_{0}^{1} x^2 dx$<br/>
#
#    El algoritmo Monte Carlo en pseudocódigo es el siguiente:
# >hits=0<br/>
#  for i from 1 to N<br/>
#  &nbsp;&nbsp;&nbsp;&nbsp;Generate two random numbers r1 and r2 between 0 and 1<br/>
#  &nbsp;&nbsp;&nbsp;&nbsp;If r2<r1^2 then hits=hits+1<br/>
#  end for<br/>
#  return hits/N
#
#     HINT: Use las funciones `runif()` y `rnorm()`.
# 3. Crea una lista de cinco matrices numéricas y ordena cada una de ellas tras su creación (el elemento [1,1] tendrá el valor menor y el [#filas,#columnas] el valor mayor).
# 4. Calcula el valor mínimo de cada columna de una matriz, pero suponiendo que los números impares son negativos y los pares positivos.
# 5. Dada una matriz devuelve una lista de todos los valores mayores que 7 de cada fila.

# %% [markdown]
# # Programación con Tidyverse (paquete `purrr`)
# * `map()`: permite aplicar una función con un único argumento a un vector
# * `map2()`: permite aplicar una función con dos argumentos a un vector
# * `pmap()`: permite aplicar una función con múltiples argumentos a un vector
#
# https://dcl-prog.stanford.edu/purrr-basics.html

# %%
library(tidyverse)

?map
# Out:
# map                   package:purrr                    R Documentation
#
# r
#
# n:
#
#      The map functions transform their input by applying a function to
#      each element of a list or atomic vector and returning an object of
#      the same length as the input.
#
#         • ‘map()’ always returns a list. See the ‘modify()’ family for
#           versions that return an object of the same type as the input.
#
#         • ‘map_lgl()’, ‘map_int()’, ‘map_dbl()’ and ‘map_chr()’ return
#           an atomic vector of the indicated type (or die trying). For
#           these functions, ‘.f’ must return a length-1 vector of the
#           appropriate type.
#
#         • ‘map_vec()’ simplifies to the common type of the output. It
#           works with most types of simple vectors like Date, POSIXct,
#           factors, etc.
#
#         • ‘walk()’ calls ‘.f’ for its side-effect and returns the input
#           ‘.x’.
#
# e:
#
#      map(.x, .f, ..., .progress = FALSE)
#
#      map_lgl(.x, .f, ..., .progress = FALSE)
#
#      map_int(.x, .f, ..., .progress = FALSE)
#
#      map_dbl(.x, .f, ..., .progress = FALSE)
#
#      map_chr(.x, .f, ..., .progress = FALSE)
#
#      map_vec(.x, .f, ..., .ptype = NULL, .progress = FALSE)
#
#      walk(.x, .f, ..., .progress = FALSE)
#
# s:
#
#       .x: A list or atomic vector.
#
#       .f: A function, specified in one of the following ways:
#
#             • A named function, e.g. ‘mean’.
#
#             • An anonymous function, e.g. \(x) x + 1 or ‘function(x) x
#               + 1’.
#
#             • A formula, e.g. ‘~ .x + 1’. You must use ‘.x’ to refer to
#               the first argument. Only recommended if you require
#               backward compatibility with older versions of R.
#
#             • A string, integer, or list, e.g. ‘"idx"’, ‘1’, or
#               ‘list("idx", 1)’ which are shorthand for \(x) pluck(x,
#               "idx"), \(x) pluck(x, 1), and \(x) pluck(x, "idx", 1)
#               respectively. Optionally supply ‘.default’ to set a
#               default value if the indexed element is ‘NULL’ or does
#               not exist.
#
#      ...: Additional arguments passed on to the mapped function.
#
#           We now generally recommend against using ‘...’ to pass
#           additional (constant) arguments to ‘.f’. Instead use a
#           shorthand anonymous function:
#
#           # Instead of
#           x |> map(f, 1, 2, collapse = ",")
#           # do:
#           x |> map(\(x) f(x, 1, 2, collapse = ","))
#
#           This makes it easier to understand which arguments belong to
#           which function and will tend to yield better error messages.
#
# .progress: Whether to show a progress bar. Use ‘TRUE’ to turn on a
#           basic progress bar, use a string to give it a name, or see
#           progress_bars for more details.
#
#   .ptype: If ‘NULL’, the default, the output type is the common type of
#           the elements of the result. Otherwise, supply a "prototype"
#           giving the desired type of output.
#
# e:
#
#      The output length is determined by the length of the input. The
#      output names are determined by the input names. The output type is
#      determined by the suffix:
#
#         • No suffix: a list; ‘.f()’ can return anything.
#
#         • _lgl(), _int(), _dbl(), _chr() return a logical, integer,
#           double, or character vector respectively; ‘.f()’ must return
#           a compatible atomic vector of length 1.
#
#         • _vec() return an atomic or S3 vector, the same type that ‘.f’
#           returns. ‘.f’ can return pretty much any type of vector, as
#           long as its length 1.
#
#         • ‘walk()’ returns the input ‘.x’ (invisibly). This makes it
#           easy to use in a pipe. The return value of ‘.f()’ is ignored.
#
#      Any errors thrown by ‘.f’ will be wrapped in an error with class
#      purrr_error_indexed.
#
# o:
#
#      ‘map_if()’ for applying a function to only those elements of ‘.x’
#      that meet a specified condition.
#
#      Other map variants: ‘imap()’, ‘lmap()’, ‘map2()’, ‘map_depth()’,
#      ‘map_if()’, ‘modify()’, ‘pmap()’
#
# s:
#
#      # Compute normal distributions from an atomic vector
#      1:10 |>
#        map(rnorm, n = 10)
#
#      # You can also use an anonymous function
#      1:10 |>
#        map(\(x) rnorm(10, x))
#
#      # Simplify output to a vector instead of a list by computing the mean of the distributions
#      1:10 |>
#        map(rnorm, n = 10) |>  # output a list
#        map_dbl(mean)           # output an atomic vector
#
#      # Using set_names() with character vectors is handy to keep track
#      # of the original inputs:
#      set_names(c("foo", "bar")) |> map_chr(paste0, ":suffix")
#
#      # Working with lists
#      favorite_desserts <- list(Sophia = "banana bread", Eliott = "pancakes", Karina = "chocolate cake")
#      favorite_desserts |> map_chr(\(food) paste(food, "rocks!"))
#
#      # Extract by name or position
#      # .default specifies value for elements that are missing or NULL
#      l1 <- list(list(a = 1L), list(a = NULL, b = 2L), list(b = 3L))
#      l1 |> map("a", .default = "???")
#      l1 |> map_int("b", .default = NA)
#      l1 |> map_int(2, .default = NA)
#
#      # Supply multiple values to index deeply into a list
#      l2 <- list(
#        list(num = 1:3,     letters[1:3]),
#        list(num = 101:103, letters[4:6]),
#        list()
#      )
#      l2 |> map(c(2, 2))
#
#      # Use a list to build an extractor that mixes numeric indices and names,
#      # and .default to provide a default value if the element does not exist
#      l2 |> map(list("num", 3))
#      l2 |> map_int(list("num", 3), .default = NA)
#
#      # Working with data frames
#      # Use map_lgl(), map_dbl(), etc to return a vector instead of a list:
#      mtcars |> map_dbl(sum)
#
#      # A more realistic example: split a data frame into pieces, fit a
#      # model to each piece, summarise and extract R^2
#      mtcars |>
#        split(mtcars$cyl) |>
#        map(\(df) lm(mpg ~ wt, data = df)) |>
#        map(summary) |>
#        map_dbl("r.squared")

# %%
starwars %>% select(height, mass) %>% map(mean, na.rm=TRUE)
# Out:
# $height
# [1] 174.6049
#
# $mass
# [1] 97.31186

# %%
starwars %>% select(height, mass) %>% mean(na.rm=TRUE)
# Out:
# Warning message in mean.default(., na.rm = TRUE):
# “argument is not numeric or logical: returning NA”
# [1] NA

# %%
print(starwars %>% select(height, mass) %>% map_dbl(mean, na.rm=TRUE))
# Out:
#    height      mass
# 174.60494  97.31186

# %%
starwars %>% map_if(is.numeric, mean, na.rm=TRUE)
# Out:
# $name
#  [1] "Luke Skywalker"        "C-3PO"                 "R2-D2"
#  [4] "Darth Vader"           "Leia Organa"           "Owen Lars"
#  [7] "Beru Whitesun Lars"    "R5-D4"                 "Biggs Darklighter"
# [10] "Obi-Wan Kenobi"        "Anakin Skywalker"      "Wilhuff Tarkin"
# [13] "Chewbacca"             "Han Solo"              "Greedo"
# [16] "Jabba Desilijic Tiure" "Wedge Antilles"        "Jek Tono Porkins"
# [19] "Yoda"                  "Palpatine"             "Boba Fett"
# [22] "IG-88"                 "Bossk"                 "Lando Calrissian"
# [25] "Lobot"                 "Ackbar"                "Mon Mothma"
# [28] "Arvel Crynyd"          "Wicket Systri Warrick" "Nien Nunb"
# [31] "Qui-Gon Jinn"          "Nute Gunray"           "Finis Valorum"
# [34] "Padmé Amidala"         "Jar Jar Binks"         "Roos Tarpals"
# [37] "Rugor Nass"            "Ric Olié"              "Watto"
# [40] "Sebulba"               "Quarsh Panaka"         "Shmi Skywalker"
# [43] "Darth Maul"            "Bib Fortuna"           "Ayla Secura"
# [46] "Ratts Tyerel"          "Dud Bolt"              "Gasgano"
# [49] "Ben Quadinaros"        "Mace Windu"            "Ki-Adi-Mundi"
# [52] "Kit Fisto"             "Eeth Koth"             "Adi Gallia"
# [55] "Saesee Tiin"           "Yarael Poof"           "Plo Koon"
# [58] "Mas Amedda"            "Gregar Typho"          "Cordé"
# [61] "Cliegg Lars"           "Poggle the Lesser"     "Luminara Unduli"
# [64] "Barriss Offee"         "Dormé"                 "Dooku"
# [67] "Bail Prestor Organa"   "Jango Fett"            "Zam Wesell"
# [70] "Dexter Jettster"       "Lama Su"               "Taun We"
# [73] "Jocasta Nu"            "R4-P17"                "Wat Tambor"
# [76] "San Hill"              "Shaak Ti"              "Grievous"
# [79] "Tarfful"               "Raymus Antilles"       "Sly Moore"
# [82] "Tion Medon"            "Finn"                  "Rey"
# [85] "Poe Dameron"           "BB8"                   "Captain Phasma"
#
# $height
# [1] 174.6049
#
# $mass
# [1] 97.31186
#
# $hair_color
#  [1] "blond"         NA              NA              "none"
#  [5] "brown"         "brown, grey"   "brown"         NA
#  [9] "black"         "auburn, white" "blond"         "auburn, grey"
# [13] "brown"         "brown"         NA              NA
# [17] "brown"         "brown"         "white"         "grey"
# [21] "black"         "none"          "none"          "black"
# [25] "none"          "none"          "auburn"        "brown"
# [29] "brown"         "none"          "brown"         "none"
# [33] "blond"         "brown"         "none"          "none"
# [37] "none"          "brown"         "black"         "none"
# [41] "black"         "black"         "none"          "none"
# [45] "none"          "none"          "none"          "none"
# [49] "none"          "none"          "white"         "none"
# [53] "black"         "none"          "none"          "none"
# [57] "none"          "none"          "black"         "brown"
# [61] "brown"         "none"          "black"         "black"
# [65] "brown"         "white"         "black"         "black"
# [69] "blonde"        "none"          "none"          "none"
# [73] "white"         "none"          "none"          "none"
# [77] "none"          "none"          "brown"         "brown"
# [81] "none"          "none"          "black"         "brown"
# [85] "brown"         "none"          "none"
#
# $skin_color
#  [1] "fair"                "gold"                "white, blue"
#  [4] "white"               "light"               "light"
#  [7] "light"               "white, red"          "light"
# [10] "fair"                "fair"                "fair"
# [13] "unknown"             "fair"                "green"
# [16] "green-tan, brown"    "fair"                "fair"
# [19] "green"               "pale"                "fair"
# [22] "metal"               "green"               "dark"
# [25] "light"               "brown mottle"        "fair"
# [28] "fair"                "brown"               "grey"
# [31] "fair"                "mottled green"       "fair"
# [34] "light"               "orange"              "grey"
# [37] "green"               "fair"                "blue, grey"
# [40] "grey, red"           "dark"                "fair"
# [43] "red"                 "pale"                "blue"
# [46] "grey, blue"          "blue, grey"          "white, blue"
# [49] "grey, green, yellow" "dark"                "pale"
# [52] "green"               "brown"               "dark"
# [55] "pale"                "white"               "orange"
# [58] "blue"                "dark"                "light"
# [61] "fair"                "green"               "yellow"
# [64] "yellow"              "light"               "fair"
# [67] "tan"                 "tan"                 "fair, green, yellow"
# [70] "brown"               "grey"                "grey"
# [73] "fair"                "silver, red"         "green, grey"
# [76] "grey"                "red, blue, white"    "brown, white"
# [79] "brown"               "light"               "pale"
# [82] "grey"                "dark"                "light"
# [85] "light"               "none"                "none"
#
# $eye_color
#  [1] "blue"          "yellow"        "red"           "yellow"
#  [5] "brown"         "blue"          "blue"          "red"
#  [9] "brown"         "blue-gray"     "blue"          "blue"
# [13] "blue"          "brown"         "black"         "orange"
# [17] "hazel"         "blue"          "brown"         "yellow"
# [21] "brown"         "red"           "red"           "brown"
# [25] "blue"          "orange"        "blue"          "brown"
# [29] "brown"         "black"         "blue"          "red"
# [33] "blue"          "brown"         "orange"        "orange"
# [37] "orange"        "blue"          "yellow"        "orange"
# [41] "brown"         "brown"         "yellow"        "pink"
# [45] "hazel"         "unknown"       "yellow"        "black"
# [49] "orange"        "brown"         "yellow"        "black"
# [53] "brown"         "blue"          "orange"        "yellow"
# [57] "black"         "blue"          "brown"         "brown"
# [61] "blue"          "yellow"        "blue"          "blue"
# [65] "brown"         "brown"         "brown"         "brown"
# [69] "yellow"        "yellow"        "black"         "black"
# [73] "blue"          "red, blue"     "unknown"       "gold"
# [77] "black"         "green, yellow" "blue"          "brown"
# [81] "white"         "black"         "dark"          "hazel"
# [85] "brown"         "black"         "unknown"
#
# $birth_year
# [1] 87.56512
#
# $sex
#  [1] "male"           "none"           "none"           "male"
#  [5] "female"         "male"           "female"         "none"
#  [9] "male"           "male"           "male"           "male"
# [13] "male"           "male"           "male"           "hermaphroditic"
# [17] "male"           NA               "male"           "male"
# [21] "male"           "none"           "male"           "male"
# [25] "male"           "male"           "female"         "male"
# [29] "male"           "male"           "male"           "male"
# [33] "male"           "female"         "male"           "male"
# [37] "male"           "male"           "male"           "male"
# [41] "male"           "female"         "male"           "male"
# [45] "female"         "male"           "male"           "male"
# [49] "male"           "male"           "male"           "male"
# [53] "male"           "female"         "male"           "male"
# [57] "male"           "male"           NA               NA
# [61] "male"           "male"           "female"         "female"
# [65] "female"         "male"           "male"           "male"
# [69] "female"         "male"           "male"           "female"
# [73] "female"         "none"           "male"           "male"
# [77] "female"         "male"           "male"           "male"
# [81] NA               "male"           "male"           "female"
# [85] "male"           "none"           "female"
#
# $gender
#  [1] "masculine" "masculine" "masculine" "masculine" "feminine"  "masculine"
#  [7] "feminine"  "masculine" "masculine" "masculine" "masculine" "masculine"
# [13] "masculine" "masculine" "masculine" "masculine" "masculine" NA
# [19] "masculine" "masculine" "masculine" "masculine" "masculine" "masculine"
# [25] "masculine" "masculine" "feminine"  "masculine" "masculine" "masculine"
# [31] "masculine" "masculine" "masculine" "feminine"  "masculine" "masculine"
# [37] "masculine" "masculine" "masculine" "masculine" "masculine" "feminine"
# [43] "masculine" "masculine" "feminine"  "masculine" "masculine" "masculine"
# [49] "masculine" "masculine" "masculine" "masculine" "masculine" "feminine"
# [55] "masculine" "masculine" "masculine" "masculine" NA          NA
# [61] "masculine" "masculine" "feminine"  "feminine"  "feminine"  "masculine"
# [67] "masculine" "masculine" "feminine"  "masculine" "masculine" "feminine"
# [73] "feminine"  "feminine"  "masculine" "masculine" "feminine"  "masculine"
# [79] "masculine" "masculine" NA          "masculine" "masculine" "feminine"
# [85] "masculine" "masculine" "feminine"
#
# $homeworld
#  [1] "Tatooine"       "Tatooine"       "Naboo"          "Tatooine"
#  [5] "Alderaan"       "Tatooine"       "Tatooine"       "Tatooine"
#  [9] "Tatooine"       "Stewjon"        "Tatooine"       "Eriadu"
# [13] "Kashyyyk"       "Corellia"       "Rodia"          "Nal Hutta"
# [17] "Corellia"       "Bestine IV"     NA               "Naboo"
# [21] "Kamino"         NA               "Trandosha"      "Socorro"
# [25] "Bespin"         "Mon Cala"       "Chandrila"      NA
# [29] "Endor"          "Sullust"        NA               "Cato Neimoidia"
# [33] "Coruscant"      "Naboo"          "Naboo"          "Naboo"
# [37] "Naboo"          "Naboo"          "Toydaria"       "Malastare"
# [41] "Naboo"          "Tatooine"       "Dathomir"       "Ryloth"
# [45] "Ryloth"         "Aleen Minor"    "Vulpter"        "Troiken"
# [49] "Tund"           "Haruun Kal"     "Cerea"          "Glee Anselm"
# [53] "Iridonia"       "Coruscant"      "Iktotch"        "Quermia"
# [57] "Dorin"          "Champala"       "Naboo"          "Naboo"
# [61] "Tatooine"       "Geonosis"       "Mirial"         "Mirial"
# [65] "Naboo"          "Serenno"        "Alderaan"       "Concord Dawn"
# [69] "Zolan"          "Ojom"           "Kamino"         "Kamino"
# [73] "Coruscant"      NA               "Skako"          "Muunilinst"
# [77] "Shili"          "Kalee"          "Kashyyyk"       "Alderaan"
# [81] "Umbara"         "Utapau"         NA               NA
# [85] NA               NA               NA
#
# $species
#  [1] "Human"          "Droid"          "Droid"          "Human"
#  [5] "Human"          "Human"          "Human"          "Droid"
#  [9] "Human"          "Human"          "Human"          "Human"
# [13] "Wookiee"        "Human"          "Rodian"         "Hutt"
# [17] "Human"          NA               "Yoda's species" "Human"
# [21] "Human"          "Droid"          "Trandoshan"     "Human"
# [25] "Human"          "Mon Calamari"   "Human"          "Human"
# [29] "Ewok"           "Sullustan"      "Human"          "Neimodian"
# [33] "Human"          "Human"          "Gungan"         "Gungan"
# [37] "Gungan"         "Human"          "Toydarian"      "Dug"
# [41] "Human"          "Human"          "Zabrak"         "Twi'lek"
# [45] "Twi'lek"        "Aleena"         "Vulptereen"     "Xexto"
# [49] "Toong"          "Human"          "Cerean"         "Nautolan"
# [53] "Zabrak"         "Tholothian"     "Iktotchi"       "Quermian"
# [57] "Kel Dor"        "Chagrian"       NA               NA
# [61] "Human"          "Geonosian"      "Mirialan"       "Mirialan"
# [65] "Human"          "Human"          "Human"          "Human"
# [69] "Clawdite"       "Besalisk"       "Kaminoan"       "Kaminoan"
# [73] "Human"          "Droid"          "Skakoan"        "Muun"
# [77] "Togruta"        "Kaleesh"        "Wookiee"        "Human"
# [81] NA               "Pau'an"         "Human"          "Human"
# [85] "Human"          "Droid"          "Human"
#
# $films
# $films[[1]]
# [1] "A New Hope"              "The Empire Strikes Back"
# [3] "Return of the Jedi"      "Revenge of the Sith"
# [5] "The Force Awakens"
#
# $films[[2]]
# [1] "A New Hope"              "The Empire Strikes Back"
# [3] "Return of the Jedi"      "The Phantom Menace"
# [5] "Attack of the Clones"    "Revenge of the Sith"
#
# $films[[3]]
# [1] "A New Hope"              "The Empire Strikes Back"
# [3] "Return of the Jedi"      "The Phantom Menace"
# [5] "Attack of the Clones"    "Revenge of the Sith"
# [7] "The Force Awakens"
#
# $films[[4]]
# [1] "A New Hope"              "The Empire Strikes Back"
# [3] "Return of the Jedi"      "Revenge of the Sith"
#
# $films[[5]]
# [1] "A New Hope"              "The Empire Strikes Back"
# [3] "Return of the Jedi"      "Revenge of the Sith"
# [5] "The Force Awakens"
#
# $films[[6]]
# [1] "A New Hope"           "Attack of the Clones" "Revenge of the Sith"
#
# $films[[7]]
# [1] "A New Hope"           "Attack of the Clones" "Revenge of the Sith"
#
# $films[[8]]
# [1] "A New Hope"
#
# $films[[9]]
# [1] "A New Hope"
#
# $films[[10]]
# [1] "A New Hope"              "The Empire Strikes Back"
# [3] "Return of the Jedi"      "The Phantom Menace"
# [5] "Attack of the Clones"    "Revenge of the Sith"
#
# $films[[11]]
# [1] "The Phantom Menace"   "Attack of the Clones" "Revenge of the Sith"
#
# $films[[12]]
# [1] "A New Hope"          "Revenge of the Sith"
#
# $films[[13]]
# [1] "A New Hope"              "The Empire Strikes Back"
# [3] "Return of the Jedi"      "Revenge of the Sith"
# [5] "The Force Awakens"
#
# $films[[14]]
# [1] "A New Hope"              "The Empire Strikes Back"
# [3] "Return of the Jedi"      "The Force Awakens"
#
# $films[[15]]
# [1] "A New Hope"
#
# $films[[16]]
# [1] "A New Hope"         "Return of the Jedi" "The Phantom Menace"
#
# $films[[17]]
# [1] "A New Hope"              "The Empire Strikes Back"
# [3] "Return of the Jedi"
#
# $films[[18]]
# [1] "A New Hope"
#
# $films[[19]]
# [1] "The Empire Strikes Back" "Return of the Jedi"
# [3] "The Phantom Menace"      "Attack of the Clones"
# [5] "Revenge of the Sith"
#
# $films[[20]]
# [1] "The Empire Strikes Back" "Return of the Jedi"
# [3] "The Phantom Menace"      "Attack of the Clones"
# [5] "Revenge of the Sith"
#
# $films[[21]]
# [1] "The Empire Strikes Back" "Return of the Jedi"
# [3] "Attack of the Clones"
#
# $films[[22]]
# [1] "The Empire Strikes Back"
#
# $films[[23]]
# [1] "The Empire Strikes Back"
#
# $films[[24]]
# [1] "The Empire Strikes Back" "Return of the Jedi"
#
# $films[[25]]
# [1] "The Empire Strikes Back"
#
# $films[[26]]
# [1] "Return of the Jedi" "The Force Awakens"
#
# $films[[27]]
# [1] "Return of the Jedi"
#
# $films[[28]]
# [1] "Return of the Jedi"
#
# $films[[29]]
# [1] "Return of the Jedi"
#
# $films[[30]]
# [1] "Return of the Jedi"
#
# $films[[31]]
# [1] "The Phantom Menace"
#
# $films[[32]]
# [1] "The Phantom Menace"   "Attack of the Clones" "Revenge of the Sith"
#
# $films[[33]]
# [1] "The Phantom Menace"
#
# $films[[34]]
# [1] "The Phantom Menace"   "Attack of the Clones" "Revenge of the Sith"
#
# $films[[35]]
# [1] "The Phantom Menace"   "Attack of the Clones"
#
# $films[[36]]
# [1] "The Phantom Menace"
#
# $films[[37]]
# [1] "The Phantom Menace"
#
# $films[[38]]
# [1] "The Phantom Menace"
#
# $films[[39]]
# [1] "The Phantom Menace"   "Attack of the Clones"
#
# $films[[40]]
# [1] "The Phantom Menace"
#
# $films[[41]]
# [1] "The Phantom Menace"
#
# $films[[42]]
# [1] "The Phantom Menace"   "Attack of the Clones"
#
# $films[[43]]
# [1] "The Phantom Menace"
#
# $films[[44]]
# [1] "Return of the Jedi"
#
# $films[[45]]
# [1] "The Phantom Menace"   "Attack of the Clones" "Revenge of the Sith"
#
# $films[[46]]
# [1] "The Phantom Menace"
#
# $films[[47]]
# [1] "The Phantom Menace"
#
# $films[[48]]
# [1] "The Phantom Menace"
#
# $films[[49]]
# [1] "The Phantom Menace"
#
# $films[[50]]
# [1] "The Phantom Menace"   "Attack of the Clones" "Revenge of the Sith"
#
# $films[[51]]
# [1] "The Phantom Menace"   "Attack of the Clones" "Revenge of the Sith"
#
# $films[[52]]
# [1] "The Phantom Menace"   "Attack of the Clones" "Revenge of the Sith"
#
# $films[[53]]
# [1] "The Phantom Menace"  "Revenge of the Sith"
#
# $films[[54]]
# [1] "The Phantom Menace"  "Revenge of the Sith"
#
# $films[[55]]
# [1] "The Phantom Menace"  "Revenge of the Sith"
#
# $films[[56]]
# [1] "The Phantom Menace"
#
# $films[[57]]
# [1] "The Phantom Menace"   "Attack of the Clones" "Revenge of the Sith"
#
# $films[[58]]
# [1] "The Phantom Menace"   "Attack of the Clones"
#
# $films[[59]]
# [1] "Attack of the Clones"
#
# $films[[60]]
# [1] "Attack of the Clones"
#
# $films[[61]]
# [1] "Attack of the Clones"
#
# $films[[62]]
# [1] "Attack of the Clones" "Revenge of the Sith"
#
# $films[[63]]
# [1] "Attack of the Clones" "Revenge of the Sith"
#
# $films[[64]]
# [1] "Attack of the Clones"
#
# $films[[65]]
# [1] "Attack of the Clones"
#
# $films[[66]]
# [1] "Attack of the Clones" "Revenge of the Sith"
#
# $films[[67]]
# [1] "Attack of the Clones" "Revenge of the Sith"
#
# $films[[68]]
# [1] "Attack of the Clones"
#
# $films[[69]]
# [1] "Attack of the Clones"
#
# $films[[70]]
# [1] "Attack of the Clones"
#
# $films[[71]]
# [1] "Attack of the Clones"
#
# $films[[72]]
# [1] "Attack of the Clones"
#
# $films[[73]]
# [1] "Attack of the Clones"
#
# $films[[74]]
# [1] "Attack of the Clones" "Revenge of the Sith"
#
# $films[[75]]
# [1] "Attack of the Clones"
#
# $films[[76]]
# [1] "Attack of the Clones"
#
# $films[[77]]
# [1] "Attack of the Clones" "Revenge of the Sith"
#
# $films[[78]]
# [1] "Revenge of the Sith"
#
# $films[[79]]
# [1] "Revenge of the Sith"
#
# $films[[80]]
# [1] "A New Hope"          "Revenge of the Sith"
#
# $films[[81]]
# [1] "Attack of the Clones" "Revenge of the Sith"
#
# $films[[82]]
# [1] "Revenge of the Sith"
#
# $films[[83]]
# [1] "The Force Awakens"
#
# $films[[84]]
# [1] "The Force Awakens"
#
# $films[[85]]
# [1] "The Force Awakens"
#
# $films[[86]]
# [1] "The Force Awakens"
#
# $films[[87]]
# [1] "The Force Awakens"
#
#
# $vehicles
# $vehicles[[1]]
# [1] "Snowspeeder"           "Imperial Speeder Bike"
#
# $vehicles[[2]]
# character(0)
#
# $vehicles[[3]]
# character(0)
#
# $vehicles[[4]]
# character(0)
#
# $vehicles[[5]]
# [1] "Imperial Speeder Bike"
#
# $vehicles[[6]]
# character(0)
#
# $vehicles[[7]]
# character(0)
#
# $vehicles[[8]]
# character(0)
#
# $vehicles[[9]]
# character(0)
#
# $vehicles[[10]]
# [1] "Tribubble bongo"
#
# $vehicles[[11]]
# [1] "Zephyr-G swoop bike" "XJ-6 airspeeder"
#
# $vehicles[[12]]
# character(0)
#
# $vehicles[[13]]
# [1] "AT-ST"
#
# $vehicles[[14]]
# character(0)
#
# $vehicles[[15]]
# character(0)
#
# $vehicles[[16]]
# character(0)
#
# $vehicles[[17]]
# [1] "Snowspeeder"
#
# $vehicles[[18]]
# character(0)
#
# $vehicles[[19]]
# character(0)
#
# $vehicles[[20]]
# character(0)
#
# $vehicles[[21]]
# character(0)
#
# $vehicles[[22]]
# character(0)
#
# $vehicles[[23]]
# character(0)
#
# $vehicles[[24]]
# character(0)
#
# $vehicles[[25]]
# character(0)
#
# $vehicles[[26]]
# character(0)
#
# $vehicles[[27]]
# character(0)
#
# $vehicles[[28]]
# character(0)
#
# $vehicles[[29]]
# character(0)
#
# $vehicles[[30]]
# character(0)
#
# $vehicles[[31]]
# [1] "Tribubble bongo"
#
# $vehicles[[32]]
# character(0)
#
# $vehicles[[33]]
# character(0)
#
# $vehicles[[34]]
# character(0)
#
# $vehicles[[35]]
# character(0)
#
# $vehicles[[36]]
# character(0)
#
# $vehicles[[37]]
# character(0)
#
# $vehicles[[38]]
# character(0)
#
# $vehicles[[39]]
# character(0)
#
# $vehicles[[40]]
# character(0)
#
# $vehicles[[41]]
# character(0)
#
# $vehicles[[42]]
# character(0)
#
# $vehicles[[43]]
# [1] "Sith speeder"
#
# $vehicles[[44]]
# character(0)
#
# $vehicles[[45]]
# character(0)
#
# $vehicles[[46]]
# character(0)
#
# $vehicles[[47]]
# character(0)
#
# $vehicles[[48]]
# character(0)
#
# $vehicles[[49]]
# character(0)
#
# $vehicles[[50]]
# character(0)
#
# $vehicles[[51]]
# character(0)
#
# $vehicles[[52]]
# character(0)
#
# $vehicles[[53]]
# character(0)
#
# $vehicles[[54]]
# character(0)
#
# $vehicles[[55]]
# character(0)
#
# $vehicles[[56]]
# character(0)
#
# $vehicles[[57]]
# character(0)
#
# $vehicles[[58]]
# character(0)
#
# $vehicles[[59]]
# character(0)
#
# $vehicles[[60]]
# character(0)
#
# $vehicles[[61]]
# character(0)
#
# $vehicles[[62]]
# character(0)
#
# $vehicles[[63]]
# character(0)
#
# $vehicles[[64]]
# character(0)
#
# $vehicles[[65]]
# character(0)
#
# $vehicles[[66]]
# [1] "Flitknot speeder"
#
# $vehicles[[67]]
# character(0)
#
# $vehicles[[68]]
# character(0)
#
# $vehicles[[69]]
# [1] "Koro-2 Exodrive airspeeder"
#
# $vehicles[[70]]
# character(0)
#
# $vehicles[[71]]
# character(0)
#
# $vehicles[[72]]
# character(0)
#
# $vehicles[[73]]
# character(0)
#
# $vehicles[[74]]
# character(0)
#
# $vehicles[[75]]
# character(0)
#
# $vehicles[[76]]
# character(0)
#
# $vehicles[[77]]
# character(0)
#
# $vehicles[[78]]
# [1] "Tsmeu-6 personal wheel bike"
#
# $vehicles[[79]]
# character(0)
#
# $vehicles[[80]]
# character(0)
#
# $vehicles[[81]]
# character(0)
#
# $vehicles[[82]]
# character(0)
#
# $vehicles[[83]]
# character(0)
#
# $vehicles[[84]]
# character(0)
#
# $vehicles[[85]]
# character(0)
#
# $vehicles[[86]]
# character(0)
#
# $vehicles[[87]]
# character(0)
#
#
# $starships
# $starships[[1]]
# [1] "X-wing"           "Imperial shuttle"
#
# $starships[[2]]
# character(0)
#
# $starships[[3]]
# character(0)
#
# $starships[[4]]
# [1] "TIE Advanced x1"
#
# $starships[[5]]
# character(0)
#
# $starships[[6]]
# character(0)
#
# $starships[[7]]
# character(0)
#
# $starships[[8]]
# character(0)
#
# $starships[[9]]
# [1] "X-wing"
#
# $starships[[10]]
# [1] "Jedi starfighter"         "Trade Federation cruiser"
# [3] "Naboo star skiff"         "Jedi Interceptor"
# [5] "Belbullab-22 starfighter"
#
# $starships[[11]]
# [1] "Naboo fighter"            "Trade Federation cruiser"
# [3] "Jedi Interceptor"
#
# $starships[[12]]
# character(0)
#
# $starships[[13]]
# [1] "Millennium Falcon" "Imperial shuttle"
#
# $starships[[14]]
# [1] "Millennium Falcon" "Imperial shuttle"
#
# $starships[[15]]
# character(0)
#
# $starships[[16]]
# character(0)
#
# $starships[[17]]
# [1] "X-wing"
#
# $starships[[18]]
# [1] "X-wing"
#
# $starships[[19]]
# character(0)
#
# $starships[[20]]
# character(0)
#
# $starships[[21]]
# [1] "Slave 1"
#
# $starships[[22]]
# character(0)
#
# $starships[[23]]
# character(0)
#
# $starships[[24]]
# [1] "Millennium Falcon"
#
# $starships[[25]]
# character(0)
#
# $starships[[26]]
# character(0)
#
# $starships[[27]]
# character(0)
#
# $starships[[28]]
# [1] "A-wing"
#
# $starships[[29]]
# character(0)
#
# $starships[[30]]
# [1] "Millennium Falcon"
#
# $starships[[31]]
# character(0)
#
# $starships[[32]]
# character(0)
#
# $starships[[33]]
# character(0)
#
# $starships[[34]]
# [1] "Naboo fighter"       "H-type Nubian yacht" "Naboo star skiff"
#
# $starships[[35]]
# character(0)
#
# $starships[[36]]
# character(0)
#
# $starships[[37]]
# character(0)
#
# $starships[[38]]
# [1] "Naboo Royal Starship"
#
# $starships[[39]]
# character(0)
#
# $starships[[40]]
# character(0)
#
# $starships[[41]]
# character(0)
#
# $starships[[42]]
# character(0)
#
# $starships[[43]]
# [1] "Scimitar"
#
# $starships[[44]]
# character(0)
#
# $starships[[45]]
# character(0)
#
# $starships[[46]]
# character(0)
#
# $starships[[47]]
# character(0)
#
# $starships[[48]]
# character(0)
#
# $starships[[49]]
# character(0)
#
# $starships[[50]]
# character(0)
#
# $starships[[51]]
# character(0)
#
# $starships[[52]]
# character(0)
#
# $starships[[53]]
# character(0)
#
# $starships[[54]]
# character(0)
#
# $starships[[55]]
# character(0)
#
# $starships[[56]]
# character(0)
#
# $starships[[57]]
# [1] "Jedi starfighter"
#
# $starships[[58]]
# character(0)
#
# $starships[[59]]
# [1] "Naboo fighter"
#
# $starships[[60]]
# character(0)
#
# $starships[[61]]
# character(0)
#
# $starships[[62]]
# character(0)
#
# $starships[[63]]
# character(0)
#
# $starships[[64]]
# character(0)
#
# $starships[[65]]
# character(0)
#
# $starships[[66]]
# character(0)
#
# $starships[[67]]
# character(0)
#
# $starships[[68]]
# character(0)
#
# $starships[[69]]
# character(0)
#
# $starships[[70]]
# character(0)
#
# $starships[[71]]
# character(0)
#
# $starships[[72]]
# character(0)
#
# $starships[[73]]
# character(0)
#
# $starships[[74]]
# character(0)
#
# $starships[[75]]
# character(0)
#
# $starships[[76]]
# character(0)
#
# $starships[[77]]
# character(0)
#
# $starships[[78]]
# [1] "Belbullab-22 starfighter"
#
# $starships[[79]]
# character(0)
#
# $starships[[80]]
# character(0)
#
# $starships[[81]]
# character(0)
#
# $starships[[82]]
# character(0)
#
# $starships[[83]]
# character(0)
#
# $starships[[84]]
# character(0)
#
# $starships[[85]]
# [1] "X-wing"
#
# $starships[[86]]
# character(0)
#
# $starships[[87]]
# character(0)

# %%
starwars %>% select(height, mass) %>% map(\(df) class(df))
# Out:
# $height
# [1] "integer"
#
# $mass
# [1] "numeric"

# %%
?map2
# Out:
# map2                   package:purrr                   R Documentation
#
# s
#
# n:
#
#      These functions are variants of ‘map()’ that iterate over two
#      arguments at a time.
#
# e:
#
#      map2(.x, .y, .f, ..., .progress = FALSE)
#
#      map2_lgl(.x, .y, .f, ..., .progress = FALSE)
#
#      map2_int(.x, .y, .f, ..., .progress = FALSE)
#
#      map2_dbl(.x, .y, .f, ..., .progress = FALSE)
#
#      map2_chr(.x, .y, .f, ..., .progress = FALSE)
#
#      map2_vec(.x, .y, .f, ..., .ptype = NULL, .progress = FALSE)
#
#      walk2(.x, .y, .f, ..., .progress = FALSE)
#
# s:
#
#   .x, .y: A pair of vectors, usually the same length. If not, a vector
#           of length 1 will be recycled to the length of the other.
#
#       .f: A function, specified in one of the following ways:
#
#             • A named function.
#
#             • An anonymous function, e.g. \(x, y) x + y or ‘function(x,
#               y) x + y’.
#
#             • A formula, e.g. ‘~ .x + .y’. You must use ‘.x’ to refer
#               to the current element of ‘x’ and ‘.y’ to refer to the
#               current element of ‘y’. Only recommended if you require
#               backward compatibility with older versions of R.
#
#      ...: Additional arguments passed on to the mapped function.
#
#           We now generally recommend against using ‘...’ to pass
#           additional (constant) arguments to ‘.f’. Instead use a
#           shorthand anonymous function:
#
#           # Instead of
#           x |> map(f, 1, 2, collapse = ",")
#           # do:
#           x |> map(\(x) f(x, 1, 2, collapse = ","))
#
#           This makes it easier to understand which arguments belong to
#           which function and will tend to yield better error messages.
#
# .progress: Whether to show a progress bar. Use ‘TRUE’ to turn on a
#           basic progress bar, use a string to give it a name, or see
#           progress_bars for more details.
#
#   .ptype: If ‘NULL’, the default, the output type is the common type of
#           the elements of the result. Otherwise, supply a "prototype"
#           giving the desired type of output.
#
# e:
#
#      The output length is determined by the length of the input. The
#      output names are determined by the input names. The output type is
#      determined by the suffix:
#
#         • No suffix: a list; ‘.f()’ can return anything.
#
#         • _lgl(), _int(), _dbl(), _chr() return a logical, integer,
#           double, or character vector respectively; ‘.f()’ must return
#           a compatible atomic vector of length 1.
#
#         • _vec() return an atomic or S3 vector, the same type that ‘.f’
#           returns. ‘.f’ can return pretty much any type of vector, as
#           long as its length 1.
#
#         • ‘walk()’ returns the input ‘.x’ (invisibly). This makes it
#           easy to use in a pipe. The return value of ‘.f()’ is ignored.
#
#      Any errors thrown by ‘.f’ will be wrapped in an error with class
#      purrr_error_indexed.
#
# o:
#
#      Other map variants: ‘imap()’, ‘lmap()’, ‘map()’, ‘map_depth()’,
#      ‘map_if()’, ‘modify()’, ‘pmap()’
#
# s:
#
#      x <- list(1, 1, 1)
#      y <- list(10, 20, 30)
#
#      map2(x, y, \(x, y) x + y)
#      # Or just
#      map2(x, y, `+`)
#
#      # Split into pieces, fit model to each piece, then predict
#      by_cyl <- mtcars |> split(mtcars$cyl)
#      mods <- by_cyl |> map(\(df) lm(mpg ~ wt, data = df))
#      map2(mods, by_cyl, predict)

# %%
starwars %>% select(height, mass) %>% 
    mutate(resultado=map2_dbl(height, mass, `-`)) %>% 
    head(5)
# Out:
#   height mass resultado
# 1 172     77   95
# 2 167     75   92
# 3  96     32   64
# 4 202    136   66
# 5 150     49  101

# %%
starwars %>% select_if(is.numeric) %>% head(5)
# Out:
#   height mass birth_year
# 1 172     77   19.0
# 2 167     75  112.0
# 3  96     32   33.0
# 4 202    136   41.9
# 5 150     49   19.0

# %%
?pmap
# Out:
# pmap                   package:purrr                   R Documentation
#
# l")
#
# n:
#
#      These functions are variants of ‘map()’ that iterate over multiple
#      arguments simultaneously. They are parallel in the sense that each
#      input is processed in parallel with the others, not in the sense
#      of multicore computing, i.e. they share the same notion of
#      "parallel" as ‘base::pmax()’ and ‘base::pmin()’.
#
# e:
#
#      pmap(.l, .f, ..., .progress = FALSE)
#
#      pmap_lgl(.l, .f, ..., .progress = FALSE)
#
#      pmap_int(.l, .f, ..., .progress = FALSE)
#
#      pmap_dbl(.l, .f, ..., .progress = FALSE)
#
#      pmap_chr(.l, .f, ..., .progress = FALSE)
#
#      pmap_vec(.l, .f, ..., .ptype = NULL, .progress = FALSE)
#
#      pwalk(.l, .f, ..., .progress = FALSE)
#
# s:
#
#       .l: A list of vectors. The length of ‘.l’ determines the number
#           of arguments that ‘.f’ will be called with. Arguments will be
#           supply by position if unnamed, and by name if named.
#
#           Vectors of length 1 will be recycled to any length; all other
#           elements must be have the same length.
#
#           A data frame is an important special case of ‘.l’. It will
#           cause ‘.f’ to be called once for each row.
#
#       .f: A function, specified in one of the following ways:
#
#             • A named function.
#
#             • An anonymous function, e.g. \(x, y, z) x + y / z or
#               ‘function(x, y, z) x + y / z’
#
#             • A formula, e.g. ‘~ ..1 + ..2 / ..3’. This syntax is not
#               recommended as you can only refer to arguments by
#               position.
#
#      ...: Additional arguments passed on to the mapped function.
#
#           We now generally recommend against using ‘...’ to pass
#           additional (constant) arguments to ‘.f’. Instead use a
#           shorthand anonymous function:
#
#           # Instead of
#           x |> map(f, 1, 2, collapse = ",")
#           # do:
#           x |> map(\(x) f(x, 1, 2, collapse = ","))
#
#           This makes it easier to understand which arguments belong to
#           which function and will tend to yield better error messages.
#
# .progress: Whether to show a progress bar. Use ‘TRUE’ to turn on a
#           basic progress bar, use a string to give it a name, or see
#           progress_bars for more details.
#
#   .ptype: If ‘NULL’, the default, the output type is the common type of
#           the elements of the result. Otherwise, supply a "prototype"
#           giving the desired type of output.
#
# e:
#
#      The output length is determined by the maximum length of all
#      elements of ‘.l’. The output names are determined by the names of
#      the first element of ‘.l’. The output type is determined by the
#      suffix:
#
#         • No suffix: a list; ‘.f()’ can return anything.
#
#         • _lgl(), _int(), _dbl(), _chr() return a logical, integer,
#           double, or character vector respectively; ‘.f()’ must return
#           a compatible atomic vector of length 1.
#
#         • _vec() return an atomic or S3 vector, the same type that ‘.f’
#           returns. ‘.f’ can return pretty much any type of vector, as
#           long as it is length 1.
#
#         • ‘pwalk()’ returns the input ‘.l’ (invisibly). This makes it
#           easy to use in a pipe. The return value of ‘.f()’ is ignored.
#
#      Any errors thrown by ‘.f’ will be wrapped in an error with class
#      purrr_error_indexed.
#
# o:
#
#      Other map variants: ‘imap()’, ‘lmap()’, ‘map()’, ‘map2()’,
#      ‘map_depth()’, ‘map_if()’, ‘modify()’
#
# s:
#
#      x <- list(1, 1, 1)
#      y <- list(10, 20, 30)
#      z <- list(100, 200, 300)
#      pmap(list(x, y, z), sum)
#
#      # Matching arguments by position
#      pmap(list(x, y, z), function(first, second, third) (first + third) * second)
#
#      # Matching arguments by name
#      l <- list(a = x, b = y, c = z)
#      pmap(l, function(c, b, a) (a + c) * b)
#
#      # Vectorizing a function over multiple arguments
#      df <- data.frame(
#        x = c("apple", "banana", "cherry"),
#        pattern = c("p", "n", "h"),
#        replacement = c("P", "N", "H"),
#        stringsAsFactors = FALSE
#        )
#      pmap(df, gsub)
#      pmap_chr(df, gsub)
#
#      # Use `...` to absorb unused components of input list .l
#      df <- data.frame(
#        x = 1:3,
#        y = 10:12,
#        z = letters[1:3]
#      )
#      plus <- function(x, y) x + y
#      ## Not run:
#
#      # this won't work
#      pmap(df, plus)
#      ## End(Not run)
#
#      # but this will
#      plus2 <- function(x, y, ...) x + y
#      pmap_dbl(df, plus2)
#
#      # The "p" for "parallel" in pmap() is the same as in base::pmin()
#      # and base::pmax()
#      df <- data.frame(
#        x = c(1, 2, 5),
#        y = c(5, 4, 8)
#      )
#      # all produce the same result
#      pmin(df$x, df$y)
#      map2_dbl(df$x, df$y, min)
#      pmap_dbl(df, min)
